# %%
import numpy as np
import pandas as pd
import re
import fuzzyset
from fuzzywuzzy import fuzz
import collections
import pandas_import_and_export
from constants import *

sep = " ~ " 
#a special character that will be used later

# %% [markdown]
# # Summer Reading Book Clustering, part 3: Fuzzy matching
#
# Now that we matched some of the entries to books in the OpenLibrary database, we still have two big tasks ahead of us:
# * figure out what to do with the entries that were not matched
# * cluster all entries so that a series of books can be viewed together
#
# First, import the csv of matched books created in part 2:

# %%
df = pandas_import_and_export.read_csv("matchedbooks")
df[:10]
# Out:
#                                               title             author  \
# 0                                   chestnut street       maeve binchy
# 1                                          deerskin     robin mckinley
# 2                       dreams of gods and monsters       laini taylor
# 3                                gone with the wind  margaret mitchell
# 4  green mansions: a romance of the tropical forest       w. h. hudson
# 5                                            herzog        saul bellow
# 6                                         homegoing          yaa gyasi
# 7                                    horrible bear!        ame dyckman
# 8                        it's okay to make mistakes          todd parr
# 9                                joe gould's secret    joseph mitchell
#
#    num_times_read  num_readers       matched_title     matched_author
# 0               1            1
# 1               1            1            Deerskin     Robin McKinley
# 2               1            1
# 3               1            1  Gone with the wind  Margaret Mitchell
# 4               1            1
# 5               1            1              Herzog        Saul Bellow
# 6               1            1           Homegoing          Yaa Gyasi
# 7               1            1
# 8               5            1
# 9               1            1  Joe Gould's Secret    Joseph Mitchell

# %% [markdown]
# First off, we'll clean all titles and authors.
#
# "title" and "author" fields should already have been cleaned in part 1, but there are a few steps of cleaning here that weren't done before so we'll clean them anyway.
#
# Matched titles and authors are directly from openlibrary and so far completely unprocessed.  A handful of openlibrary results have weird things like newlines or a lot of spaces in the middle of the titles, so we'll get rid of those specifically.

# %%
def consolidate_spaces(s):
    #when there are multiple spaces in a row, replace with one space.
    return re.sub(' +', ' ', s)

def remove_bad_chars(s):
    bad_chars = sep.strip() + "\n\r\t"
    return ''.join([i for i in s if not (i in bad_chars)])

def clean(s):
    s = remove_bad_chars(s)
    s = consolidate_spaces(s)
    s = s.strip().lower()
    return s
        
df['matched_title'] = df['matched_title'].apply(clean)
df['matched_author'] = df['matched_author'].apply(clean)
df['title'] = df['title'].apply(clean)
df['author'] = df['author'].apply(clean)
df[:10]
# Out:
#                                               title             author  \
# 0                                   chestnut street       maeve binchy
# 1                                          deerskin     robin mckinley
# 2                       dreams of gods and monsters       laini taylor
# 3                                gone with the wind  margaret mitchell
# 4  green mansions: a romance of the tropical forest       w. h. hudson
# 5                                            herzog        saul bellow
# 6                                         homegoing          yaa gyasi
# 7                                    horrible bear!        ame dyckman
# 8                        it's okay to make mistakes          todd parr
# 9                                joe gould's secret    joseph mitchell
#
#    num_times_read  num_readers       matched_title     matched_author
# 0               1            1
# 1               1            1            deerskin     robin mckinley
# 2               1            1
# 3               1            1  gone with the wind  margaret mitchell
# 4               1            1
# 5               1            1              herzog        saul bellow
# 6               1            1           homegoing          yaa gyasi
# 7               1            1
# 8               5            1
# 9               1            1  joe gould's secret    joseph mitchell

# %% [markdown]
# Split the matched and unmatched books into two tables so we can do separate operations on them.

# %%
dfu = df[(df.matched_author == '') & (df.matched_title == '')]
dfm = df[~((df.matched_author == '') & (df.matched_title == ''))]

del dfu['matched_author']
del dfu['matched_title']

# %% [markdown]
# Aggregate rows of dfm that have the exact same matched_title and matched_author.
#
# This is not strictly necessary, but helps with the next step--we will be creating lists of all the variations of names for the same book. If we don't do the initial aggregation, those lists will have a bunch of identical names on them.
#
# Just in case we need them later, we will save the inital user-entered info in the "title" and "author" fields, joining them with the sep character.

# %%
dfm = dfm.groupby(
    ['matched_title', 'matched_author'],
    as_index = False
).agg(
    {'num_times_read':np.sum,
     'num_readers':np.sum,
     'title': (lambda l: sep.join(l)),
     'author': (lambda l: sep.join(l))}
)
dfm[:10]
# Out:
#          matched_title       matched_author  num_times_read  num_readers  \
# 0             deerskin       robin mckinley               1            1
# 1   gone with the wind    margaret mitchell               1            1
# 2               herzog          saul bellow               1            1
# 3            homegoing            yaa gyasi               1            1
# 4   joe gould's secret      joseph mitchell               1            1
# 5     ready player one         ernest cline               1            1
# 6  tender is the night  f. scott fitzgerald               1            1
#
#                  title               author
# 0             deerskin       robin mckinley
# 1   gone with the wind    margaret mitchell
# 2               herzog          saul bellow
# 3            homegoing            yaa gyasi
# 4   joe gould's secret      joseph mitchell
# 5     ready player one         ernest cline
# 6  tender is the night  f. scott fitzgerald

# %%
#save dfm and dfu as csv's for recordkeeping purposes
pandas_import_and_export.to_csv(dfu, "dfu")
pandas_import_and_export.to_csv(dfm, "dfm")

# %% [raw]
# #for testing
# #make raw when not using
#
# dfu = pandas_import_and_export.read_csv("dfu")
# dfm = pandas_import_and_export.read_csv("dfm")
# dfu = dfu[:5000]
# dfm = dfm[:5000]

# %% [markdown]
# # It's clustering time! >:D
# The is where the real work starts.  The end goal of this part is to create book clusters, representing either a single book or a series.
#
# ### The Book object
# * count - total number of times the books was read
# * readers - total number of entries for that book (some entries report reading a book multiple times)
# * is_openlibrary - whether book's title and author are openlibrary search results or user-entered
# * other - for openlibrary books, use entered titles and authors that matched to those (not currently used for anything)

# %%
#general functions used in the book object

#for use with fuzzydict, see below
def make_key(title, author):
    return title + sep + author

# %%
class Book:
    
    def __init__(self, count, readers, title, author, is_openlibrary,
                 other=None):

        self.count = count
        self.readers = readers
        self.title = title
        self.author = author
        self.is_openlibrary = is_openlibrary
        self.other = other
        
        if other != None: assert(is_openlibrary)
        
    def equals(self, book):
        return self.title == book.title and self.author == book.author
    
    def rep(self):
        return (self.count, self.readers, self.title, self.author)
        
    def key(self):
        return make_key(self.title, self.author)

# %%
b1 = Book(3, 3, "Harry Potter and the Curse of the User-entered Data", "J. K. Rowling",
         is_openlibrary=True, other = ["\'harry potter and the curse of user entered data\'", "jk rowling"])

b2 = Book(21, 2, "Harry Potter and the Prisoner of OpenLibrary API", "J. K. Rowling", is_openlibrary=True)

b3 = Book(1, 1, "hary porter and the something something ajds;lkhfdsds", "jk rowling ;D", is_openlibrary=False)

b1.rep()
# Out:
# (3, 3, 'Harry Potter and the Curse of the User-entered Data', 'J. K. Rowling')

# %% [markdown]
# ### The Cluster object
# * count - total number of times the books in that cluster were read
# * readers - total number of entries for a book in the cluster (some entries report reading a book multiple times)
# * title - the title of the cluster (which is, in practice, the title of one of the most popular books in the cluster)
# * author - author of the cluster
# * contents and o_contents
#     * contents contains user-entered information
#     * o_contents contains information from openlibrary search results.
#     * both are lists of books

# %%
#general functions used in the cluster object
 
def sort_booklist(l):
    #sort booklist by count or # readers, most popular first
    if ORDER_BOOKS_BY_READERS: key = (lambda b: b.readers)
    else: key = (lambda b: b.count)
    return sorted(l, reverse=True, key=key)

def rep_booklist(l):
    #printable string representation of a booklist
    m = []
    for book in l:
        m.append(book.rep())
    return m

# %%
class Cluster:
    
    def __init__(self, book):
        self.count = book.count
        self.readers = book.readers
        self.title = book.title
        self.author =  book.author
        
        self.contents = []
        self.o_contents = []
        
        if book.is_openlibrary:
            self.o_contents.append(book)
        else:
            self.contents.append(book)
        
    def add_book(self, book):
                    
        self.count = self.count + book.count
        self.readers = self.readers + book.readers
        
        if book.is_openlibrary:
            self.o_contents.append(book)
        else:
            self.contents.append(book)
        
    def sort_contents(self):
        self.contents = sort_booklist(self.contents)
        self.o_contents = sort_booklist(self.o_contents)
        
    def rename(self):
        #resets title and author of cluster to title and author of most-read entry
        #with preference given to openlibrary entries.
        self.sort_contents()
        
        if self.o_contents == []: contents_to_use = self.contents
        else: contents_to_use = self.o_contents
        if len(contents_to_use) <= 1: return

        self.title = contents_to_use[0].title
        
        for book in contents_to_use:
            if book.author != "":
                self.author = book.author
                break    
        
    def engulf(self, c):
        #take all the books from c's contents and add them to this cluster's contents, updating relevatn counts
        
        self.count = self.count + c.get_count()
        self.readers = self.readers + c.get_readers()
        
        (c_o_contents, c_contents) = c.get_contents()
        self.o_contents = self.o_contents + c_o_contents
        self.contents = self.contents + c_contents
        
        self.rename()
                
    def key(self):
        return make_key(self.title, self.author)
        
    def get_count(self):
        return self.count
    
    def get_readers(self):
        return self.readers
        
    def get_title(self):
        return self.title
        
    def get_author(self):
        return self.author
    
    def get_contents(self):
        return (self.o_contents, self.contents)
    
    def get_contents_list(self):
        return self.o_contents + self.contents
    
    def rep(self, v):
        #returns a printable version of the cluster for debugging
        #make sure to call self.rename() or self.sort_contents() before calling this so you get sorted stuff.
        if v:
            return(self.count,
                   self.readers,
                   self.title, 
                   self.author,
                   rep_booklist(self.o_contents),
                   rep_booklist(self.contents))
        else:
            return(self.count,
                   self.readers,
                   self.title, 
                   self.author)

# %%
c = Cluster(b1)
c.rep(True)
# Out:
# (3,
#  3,
#  'Harry Potter and the Curse of the User-entered Data',
#  'J. K. Rowling',
#  [(3,
#    3,
#    'Harry Potter and the Curse of the User-entered Data',
#    'J. K. Rowling')],
#  [])

# %%
c.add_book(b2)
c.add_book(b3)
c.rename()
c.rep(True)
# Out:
# (25,
#  6,
#  'Harry Potter and the Curse of the User-entered Data',
#  'J. K. Rowling',
#  [(3,
#    3,
#    'Harry Potter and the Curse of the User-entered Data',
#    'J. K. Rowling'),
#   (21,
#    2,
#    'Harry Potter and the Prisoner of OpenLibrary API',
#    'J. K. Rowling')],
#  [(1,
#    1,
#    'hary porter and the something something ajds;lkhfdsds',
#    'jk rowling ;D')])

# %% [markdown]
# ### Matching functions
#
# These functions use the FuzzyWuzzy module to determine whether a book is a good match for a cluster.

# %%
def get_title_confidence(title1, title2):
    return fuzz.token_set_ratio(title1, title2)

def get_author_confidence(a1, a2):
    return fuzz.token_set_ratio(a1, a2)

def first_i_tokens(s, i):
    try:
        return " ".join(s.split(" ")[:i])
    except IndexError:
        #presumably there werent enough entries in the string_list
        return s
    return s

def get_partial_title_confidence(key1, key2):
    #the reason for this function is that we want to match titles such as 
    
    ptc = 0
    for i in [2,3,4]:
        p1 = first_i_tokens(key1, i)
        p2 = first_i_tokens(key2, i)
        ptc = max(ptc, fuzz.token_set_ratio(p1, p2))
        
    return ptc

def is_match_book(b, c, d):
    return is_match(b.title, b.author, c, d)

def is_match(title, author, c, d):
    #c is a cluster
    
    full_title_conf = get_title_confidence(title, c.get_title())
    partial_title_conf = get_partial_title_confidence(title, c.get_title())
    if d: 
        print(" ")
        print("full_title_conf: " + str(full_title_conf))
        print("partial_title_conf: " + str(partial_title_conf))
    
    auth_conf = []
    for cbook in c.get_contents_list():
        if cbook.author != "": auth_conf.append(get_author_confidence(author, cbook.author))
    
    if auth_conf == [] or author == "":
        if d: print("no author")
        return(full_title_conf > FULL_TITLE_CONF_CUT_NO_AUTHOR
            or partial_title_conf > PARTIAL_TITLE_CONF_CUT_NO_AUTHOR)
    else:
        avg_auth_conf = np.average(auth_conf)
        if d: print("avg_auth_conf: " + str(avg_auth_conf))
        
        return (
            (
                full_title_conf > FULL_TITLE_CONF_CUT
                or partial_title_conf > PARTIAL_TITLE_CONF_CUT
            )
            and 
            (
                avg_auth_conf > AUTH_CONF_CUT
            )
        )

# %%
c = Cluster(b1)
print(is_match_book(b2, c, True))
print(is_match_book(b3, c, True))
b4 = Book(1, 1, "hary porter and the something something ajds;lkhfdsds", "", is_openlibrary=False)
print(is_match_book(b4, c, True))
# Out:
#
# full_title_conf: 69
# partial_title_conf: 100
# avg_auth_conf: 100.0
# True
#
# full_title_conf: 58
# partial_title_conf: 92
# avg_auth_conf: 87.0
# True
#
# full_title_conf: 58
# partial_title_conf: 92
# no author
# True

# %% [markdown]
# ### The FuzzyDict object
# The above matching functions use FuzzyWuzzy, which is great for determining whether two books match.  But what if we're given a book and want to find the closest match from a long list of other books, without individually checking every book with fuzzywuzzy?
#
# That's exactly what the fuzzyset module does.  The matching can't be fine-tuned as much as FuzzyWuzzy's, but it is very fast.  The downside is, a FuzzySet is just a set of strings, wheras we would want it to store Clusters.
#
# Enter FuzzyDict!  This object contains both a dictionary (d) and a corresponding fuzzyset (fs).  The set of keys of d will be identical to the set of strings in fs, and each one will be of the form "title ~ author".  Each key's value in d will be the cluster with that title and author.

# %%
#general functions used in fuzzydict object
def sort_cluster_list(l):
    if ORDER_BOOKS_BY_READERS: key = (lambda c:c.get_readers())
    else: key = (lambda c:c.get_count())
    return sorted(l, 
                  reverse=True, 
                  key=key
    )

# %%
class FuzzyDict:
    
    def initialize(self):
        self.d = dict()
        self.fs = fuzzyset.FuzzySet(gram_size_lower=3, gram_size_upper=4)
    
    def __init__(self):
        self.initialize()
        
    def rename_clusters(self):
        #put clusters into list and attempt to rename each one
        l = self.as_list()
        for c in l:
            c.rename()
        
        #after doing this, we basically have to remake d and fs from
        #scratch, since the keys depend on the cluster title and author,
        #which may have changed.  This feels awkward, but it's necessary,
        #since the alternative is leaving the old cluster titles in fs.
        #when we add new books to our fuzzydict, we want to try to match
        #them to the better, new, titles rather than the old ones.
        self.initialize()
        for cluster in l:
            key = cluster.key()
            self.d[key] = cluster
            self.fs.add(key)
        
    def as_list(self):
        dlist = []
        for value in self.d.values():
            dlist.append(value)
        return dlist
    
    def as_sorted_list(self):
        #possibly sort clusters by number of readers instead?
        return sort_cluster_list(self.as_list())
        
    def rep(self, limit, v):
        l = list(map(
            (lambda c:c.rep(v)),
            self.as_sorted_list()
        ))
        try:
            return l[:limit]
        except IndexError:
            pass
        return l
    
       
    def add_new_cluster(self, book):
        key = book.key()
        self.d[key] = Cluster(book)
        self.fs.add(key)

    def add_book(self, book, d):
        #get best match for entered book from the fuzzyset
        #use fuzzywuzzy to make sure it is a close match
        #if so, add book to cluster
        #if not, make new cluster from book
        
        proposed_key = book.key()
        matches = self.fs.get(proposed_key)
        
        if matches == None or matches == []:
            if d: print("no match returned from fuzzyset")  
            self.add_new_cluster(book)
        else:
            (confidence, match_key) = matches[0]
            
            if d: 
                print(" ")
                print("proposed: " + proposed_key)
                print("matched: " + match_key)
                print("confidence: " + str(confidence))
                if len(matches) > 1: print("other matches: " + str(matches[1:]))
                
            match_cluster = self.d[match_key]

            if confidence > .4 and is_match_book(book, match_cluster, d):
                
                if d: print("adding to cluster")
                match_cluster.add_book(book)
                
            else: 
                if d: print("no match")     
                self.add_new_cluster(book)

# %% [markdown]
# ## Phase 1
#
# Phase 1 will only involve the openlibrary matched books (dfm).  Unlike the books in dfu, these are (mostly) garuateed to be spelled correctly and such.  Cluster together similar books and rename the clusters.

# %%
fd = FuzzyDict()
for i, row in dfm.iterrows():
    fd.add_book(
        Book(
            row.num_times_read,
            row.num_readers,
            row.matched_title, 
            row.matched_author, 
            is_openlibrary=True,
            other=(row.title, row.author)
        ),
        d=DEBUG_FUZZY_MATCHING
    )
fd.rename_clusters()
fd.rep(limit=10, v=True)
# Out:
# [(412,
#   378,
#   "harry potter and the sorcerer's stone",
#   'j. k. rowling',
#   [(99, 87, "harry potter and the sorcerer's stone", 'j. k. rowling', True),
#    (60, 59, 'harry potter and the chamber of secrets', 'j. k. rowling', True),
#    (61, 54, 'harry potter and the goblet of fire', 'j. k. rowling', True),
#    (48,
#     44,
#     'harry potter and the order of the phoenix',
#     'j. k. rowling',
#     True),
#    (42, 40, 'harry potter and the prisoner of azkaban', 'j. k. rowling', True),
#    (39, 38, 'harry potter and the half-blood prince', 'j. k. rowling', True),
#    (38, 31, 'harry potter and the deathly hallows', 'j. k. rowling', True),
#    (23, 23, 'harry potter and the cursed child', 'j. k. rowling', True),
#    (1, 1, "harry potter and the philosopher's stone", 'j. k. rowling', True),
#    (1, 1, 'harry potter, tome 3', 'j. k. rowling', True)],
#   []),
#  (199,
#   141,
#   'if you give a mouse a cookie',
#   'laura numeroff',
#   [(70, 39, 'if you give a mouse a cookie', 'laura numeroff', True),
#    (20, 19, 'if you give a moose a muffin', 'laura numeroff', True),
#    (21, 19, 'if you give a pig a pancake', 'laura numeroff', True),
#    (34, 16, 'if you give a cat a cupcake', 'laura numeroff', True),
#    (17, 16, 'if you give a dog a donut', 'laura numeroff', True),
#    (13, 13, 'if you take a mouse to school', 'laura numeroff', True),
#    (10, 10, 'if you take a mouse to the movies', 'laura numeroff', True),
#    (14, 9, 'if you give a pig a party', 'laura numeroff', True)],
#   []),
#  (114,
#   105,
#   'goodnight moon',
#   'margaret wise brown',
#   [(113, 104, 'goodnight moon', 'margaret wise brown', True),
#    (1, 1, 'goodnight moon 123', 'margaret wise brown', True)],
#   []),
#  (117,
#   92,
#   'green eggs and ham',
#   'dr. seuss',
#   [(117, 92, 'green eggs and ham', 'dr. seuss', True)],
#   []),
#  (130,
#   82,
#   'chicka chicka boom boom',
#   'martin, bill',
#   [(77, 42, 'chicka chicka boom boom', 'martin, bill', True),
#    (29,
#     23,
#     'chicka chicka boom boom',
#     'bill martin jr. & john archamba',
#     True),
#    (9, 9, 'chicka chicka abc', 'martin, bill', True),
#    (9, 5, 'chicka chicka 1 2 3', 'bill martin jr.', True),
#    (6,
#     3,
#     'chicka chicka boom boom',
#     'bill martin jr, john archambault',
#     True)],
#   []),
#  (67,
#   67,
#   'captain underpants and the perilous plot of professor poopypants',
#   'dav pilkey',
#   [(19,
#     19,
#     'captain underpants and the perilous plot of professor poopypants',
#     'dav pilkey',
#     True),
#    (14,
#     14,
#     'captain underpants and the invasion of the incredibly naughty cafeteria ladies from outer space ..',
#     'dav pilkey',
#     True),
#    (8,
#     8,
#     'captain underpants and the preposterous plight of the purple potty people (captain underpants)',
#     'dav pilkey',
#     True),
#    (8,
#     8,
#     'captain underpants and the wrath of the wicked wedgie woman',
#     'dav pilkey',
#     True),
#    (7,
#     7,
#     'captain underpants and the big, bad battle of the bionic booger boy',
#     'dav pilkey',
#     True),
#    (6,
#     6,
#     'captain underpants and the terrifying return of tippy tinkletrousers',
#     'dav pilkey',
#     True),
#    (4,
#     4,
#     'captain underpants and the big, bad battle of the bionic booger boy, part 2',
#     'dav pilkey',
#     True),
#    (1,
#     1,
#     'captain underpants and the wrath of the wicked wedgie women',
#     'dav pilkey',
#     True)],
#   []),
#  (61,
#   60,
#   'everything i never told you',
#   'celeste ng',
#   [(61, 60, 'everything i never told you', 'celeste ng', True)],
#   []),
#  (67,
#   59,
#   'fancy nancy',
#   "jane o'connor",
#   [(17, 15, 'fancy nancy', "jane o'connor", True),
#    (7, 6, 'fancy nancy and the mean girl', "jane o'connor", True),
#    (9, 6, 'fancy nancy and the mermaid ballet', "jane o'connor", True),
#    (4,
#     4,
#     'fancy nancy and the fabulous fashion boutique',
#     "jane o'connor",
#     True),
#    (4, 4, 'fancy nancy at the museum', "jane o'connor", True),
#    (4, 4, 'fancy nancy sees stars', "jane o'connor", True),
#    (4, 3, 'fancy nancy : bonjour, butterfly', "jane o'connor", True),
#    (3, 3, 'fancy nancy and the delectable cupcakes', "jane o'connor", True),
#    (3, 3, 'fancy nancy and the too-loose tooth', "jane o'connor", True),
#    (2, 2, 'fancy nancy aspiring artist', "jane o'connor", True),
#    (3, 2, 'fancy nancy fanciest doll in the universe', "jane o'connor", True),
#    (2, 2, 'fancy nancy just my luck', "jane o'connor", True),
#    (2, 2, "fancy nancy: hair dos and hair don'ts", "jane o'connor", True),
#    (1, 1, 'fancy nancy and the boy from paris', "jane o'connor", True),
#    (1, 1, 'fancy nancy and the late, late, late night', "jane o'connor", True),
#    (1, 1, 'fancy nancy, poison ivy expert', "jane o'connor", True)],
#   []),
#  (79,
#   58,
#   'hop on pop',
#   'dr. seuss',
#   [(76, 55, 'hop on pop', 'dr. seuss', True),
#    (3, 3, 'hop on pop book & cd (dr. seuss)', 'dr. seuss', True)],
#   []),
#  (88,
#   53,
#   "don't let the pigeon drive the bus!",
#   'mo willems',
#   [(64, 35, "don't let the pigeon drive the bus!", 'mo willems', True),
#    (24, 18, "don't let the pigeon stay up late!", 'mo willems', True)],
#   [])]

# %% [markdown]
# ## Phase 2
#
# Try to add the unmatched books to already created clusters, or crete new clusters if unable to do so.

# %%
for i, row in dfu.iterrows():
    fd.add_book(
        Book(
            row.num_times_read,
            row.num_readers,
            row.title, 
            row.author, 
            is_openlibrary=False
        ),
        d=DEBUG_FUZZY_MATCHING
    )
fd.rename_clusters()
fd.rep(limit=10, v=True)
# Out:
# [(412,
#   378,
#   "harry potter and the sorcerer's stone",
#   'j. k. rowling',
#   [(99, 87, "harry potter and the sorcerer's stone", 'j. k. rowling', True),
#    (60, 59, 'harry potter and the chamber of secrets', 'j. k. rowling', True),
#    (61, 54, 'harry potter and the goblet of fire', 'j. k. rowling', True),
#    (48,
#     44,
#     'harry potter and the order of the phoenix',
#     'j. k. rowling',
#     True),
#    (42, 40, 'harry potter and the prisoner of azkaban', 'j. k. rowling', True),
#    (39, 38, 'harry potter and the half-blood prince', 'j. k. rowling', True),
#    (38, 31, 'harry potter and the deathly hallows', 'j. k. rowling', True),
#    (23, 23, 'harry potter and the cursed child', 'j. k. rowling', True),
#    (1, 1, "harry potter and the philosopher's stone", 'j. k. rowling', True),
#    (1, 1, 'harry potter, tome 3', 'j. k. rowling', True)],
#   []),
#  (160,
#   156,
#   'diary of a wimpy kid',
#   'jeff kinney',
#   [(34, 34, 'diary of a wimpy kid', 'jeff kinney', True),
#    (5, 5, 'diary of a wimpy kid old school', 'jeff kinney', True),
#    (3, 3, 'diary of a wimpy kid : the long haul', '', True),
#    (2, 2, 'diary of a wimpy kid the third wheel', 'jeff kinney', True),
#    (1, 1, 'diary of a wimpy kid dog days', 'jeff kiney', True),
#    (1, 1, 'diary of a wimpy kid dog days', 'jeff kinney', True),
#    (1, 1, 'diary of a wimpy kid hard luck', '', True),
#    (1, 1, 'diary of a wimpy kid the last straw', 'jeff kinney', True)],
#   [(13, 13, 'diary of a wimpy kid: dog days', 'jeff kinney', False),
#    (11, 11, 'diary of a wimpy kid: long haul', 'jeff kinney', False),
#    (10, 10, 'diary of a wimpy kid: old school', 'jeff kinney', False),
#    (6, 6, 'diary of a wimpy kid: rodrick rules', 'jeff kinney', False),
#    (6, 6, 'diary of a wimpy kid: the ugly truth', 'jeff kinney', False),
#    (5, 5, 'diary of a wimpy kid: hard luck', 'jeff kinney', False),
#    (5, 5, 'diary of a wimpy kid: the last straw', 'jeff kinney', False),
#    (4, 4, 'diary of a wimpy kid: the long haul', 'jeff kinney', False),
#    (3, 3, 'diary of a wimpy kid double down', 'jeff kinney', False),
#    (3, 3, 'diary of a wimpy kid: cabin fever', 'jeff kinney', False),
#    (3, 3, 'diary of a wimpy kid: double down', 'jeff kinney', False),
#    (3, 3, 'diary of a wimpy kid: the third wheel', 'jeff kinney', False),
#    (2, 2, 'diary of a wimpy kid (series)', 'jeff kinney', False),
#    (2, 2, 'diary of a wimpy kid the ugly truth', '', False),
#    (6, 2, 'diary of a wimpy kid: double down', '', False),
#    (1, 1, 'diary of a wimpy kid 03', '', False),
#    (1, 1, 'diary of a wimpy kid 06', '', False),
#    (1, 1, 'diary of a wimpy kid 07', '', False),
#    (1, 1, 'diary of a wimpy kid 08', '', False),
#    (1, 1, 'diary of a wimpy kid 11', '', False),
#    (1, 1, 'diary of a wimpy kid # 7', '', False),
#    (1, 1, 'diary of a wimpy kid #2', '', False),
#    (1, 1, 'diary of a wimpy kid #7', '', False),
#    (1, 1, 'diary of a wimpy kid - double down', 'jeff kinney', False),
#    (1, 1, 'diary of a wimpy kid 2', '', False),
#    (1, 1, 'diary of a wimpy kid 6', '', False),
#    (1, 1, 'diary of a wimpy kid 7', '', False),
#    (1, 1, 'diary of a wimpy kid cabin fever', 'jeff kinny', False),
#    (1, 1, 'diary of a wimpy kid double down', '', False),
#    (1, 1, 'diary of a wimpy kid hard luck', 'jeff kinney', False),
#    (1, 1, 'diary of a wimpy kid the long hall', 'jeff kinne', False),
#    (1, 1, 'diary of a wimpy kid the long haul', 'jeff kinney', False),
#    (1, 1, 'diary of a wimpy kid: dog days', '', False),
#    (1, 1, 'diary of a wimpy kid: dog days', 'jeff kinney', False),
#    (1, 1, 'diary of a wimpy kid: cabin fever', '', False),
#    (1, 1, 'diary of a wimpy kid: dog days', '', False),
#    (1, 1, 'diary of a wimpy kid: double', 'jeff kinney', False),
#    (1, 1, 'diary of a wimpy kid: hard luck', '', False),
#    (1, 1, 'diary of a wimpy kid: rodrick rules', '', False),
#    (1,
#     1,
#     'diary of a wimpy kid: the long haul - jeff kinney',
#     'jeff kinney',
#     False),
#    (1, 1, 'diary of a wimpy kid: the third', 'jeff kinney', False),
#    (1, 1, 'diary of a wimpy kid: the ugly truth', '', False),
#    (1, 1, 'diary of the whimpy kid', '', False),
#    (1, 1, 'diary of the wimpy kid: the long haul', 'jeff kinney', False),
#    (1, 1, 'diary of wimpy kid doubble down', 'jeff kinney', False)]),
#  (199,
#   141,
#   'if you give a mouse a cookie',
#   'laura numeroff',
#   [(70, 39, 'if you give a mouse a cookie', 'laura numeroff', True),
#    (20, 19, 'if you give a moose a muffin', 'laura numeroff', True),
#    (21, 19, 'if you give a pig a pancake', 'laura numeroff', True),
#    (34, 16, 'if you give a cat a cupcake', 'laura numeroff', True),
#    (17, 16, 'if you give a dog a donut', 'laura numeroff', True),
#    (13, 13, 'if you take a mouse to school', 'laura numeroff', True),
#    (10, 10, 'if you take a mouse to the movies', 'laura numeroff', True),
#    (14, 9, 'if you give a pig a party', 'laura numeroff', True)],
#   []),
#  (121,
#   105,
#   'fancy nancy',
#   "jane o'connor",
#   [(17, 15, 'fancy nancy', "jane o'connor", True),
#    (7, 6, 'fancy nancy and the mean girl', "jane o'connor", True),
#    (9, 6, 'fancy nancy and the mermaid ballet', "jane o'connor", True),
#    (4,
#     4,
#     'fancy nancy and the fabulous fashion boutique',
#     "jane o'connor",
#     True),
#    (4, 4, 'fancy nancy at the museum', "jane o'connor", True),
#    (4, 4, 'fancy nancy sees stars', "jane o'connor", True),
#    (4, 3, 'fancy nancy : bonjour, butterfly', "jane o'connor", True),
#    (3, 3, 'fancy nancy and the delectable cupcakes', "jane o'connor", True),
#    (3, 3, 'fancy nancy and the too-loose tooth', "jane o'connor", True),
#    (2, 2, 'fancy nancy aspiring artist', "jane o'connor", True),
#    (3, 2, 'fancy nancy fanciest doll in the universe', "jane o'connor", True),
#    (2, 2, 'fancy nancy just my luck', "jane o'connor", True),
#    (2, 2, "fancy nancy: hair dos and hair don'ts", "jane o'connor", True),
#    (1, 1, 'fancy nancy and the boy from paris', "jane o'connor", True),
#    (1, 1, 'fancy nancy and the late, late, late night', "jane o'connor", True),
#    (1, 1, 'fancy nancy, poison ivy expert', "jane o'connor", True)],
#   [(3, 3, 'fancy nancy peanut butter and jellyfish', "jane o'connor", False),
#    (5, 3, 'fancy nancy tea parties', "jane o'connor", False),
#    (2, 2, 'fancy nancy best reading buddies', "jane o'connor", False),
#    (3, 2, 'fancy nancy every day is earth day', "jane o'connor", False),
#    (2, 2, 'fancy nancy explorer extraodinaire', "jane o'connor", False),
#    (3, 2, 'fancy nancy my family history', "jane o'connor", False),
#    (2, 2, 'fancy nancy tea party', "jane o'connor", False),
#    (2, 2, "fancy nancy: ooh la la it's beauty day", "jane o'connor", False),
#    (2, 1, 'fancy nancy the 100th day of school', 'jane o, connor', False),
#    (1, 1, 'fancy nancy : just my luck!', "o'connor, jane", False),
#    (1, 1, 'fancy nancy and hte posh puppy', '', False),
#    (1, 1, 'fancy nancy apples galore', "jane o'connor", False),
#    (2, 1, 'fancy nancy apples galore!', "jane o'connor", False),
#    (1, 1, 'fancy nancy apples galore!', "o'connor, jane", False),
#    (1, 1, 'fancy nancy backwards day', "jane o'connor", False),
#    (1, 1, 'fancy nancy backwards day', 'jane o?connor', False),
#    (1, 1, 'fancy nancy best reading buddies', 'jane o, connor', False),
#    (1, 1, 'fancy nancy explorer extraordinaire', "jane o'connor", False),
#    (1, 1, 'fancy nancy fancy day in room 1-a', "jane o'connor", False),
#    (1, 1, 'fancy nancy fancy day in room 1-a', 'jane o?connor', False),
#    (1, 1, 'fancy nancy it,s backward day', 'jane o, connor', False),
#    (1, 1, 'fancy nancy my family history', 'jane o, connor', False),
#    (1, 1, 'fancy nancy my family history', 'jane o?connor', False),
#    (1, 1, 'fancy nancy pajama day', "jane o'connor", False),
#    (1, 1, 'fancy nancy peanut and jelly fish', "jane o'connor", False),
#    (2, 1, 'fancy nancy spectacular spctacles', 'jane o, connor', False),
#    (1, 1, 'fancy nancy splendid speller', 'jane o, connor', False),
#    (1, 1, 'fancy nancy the 100th day of school', 'jane o connor', False),
#    (1, 1, 'fancy nancy time for puppy school', 'jane o?connor', False),
#    (1, 1, 'fancy nancy, spectacular spectacles', "jane o'conner", False),
#    (1, 1, 'fancy nancy: budding ballerina', "jane o'connor", False),
#    (1, 1, 'fancy nancy: peanut butter and jellyfish', "jane o'conner", False),
#    (1, 1, 'fancy nancy: peanut butter and jellyfish', "jane o'connor", False),
#    (1, 1, 'fancy nancy: poison ivy expert', "jane o'connor", False),
#    (1, 1, 'fancy nancy: splendid speller', "jane o'conner", False),
#    (2, 1, 'fancy nancy: time for puppy school', "jane o'connor", False)]),
#  (114,
#   105,
#   'goodnight moon',
#   'margaret wise brown',
#   [(113, 104, 'goodnight moon', 'margaret wise brown', True),
#    (1, 1, 'goodnight moon 123', 'margaret wise brown', True)],
#   []),
#  (117,
#   92,
#   'green eggs and ham',
#   'dr. seuss',
#   [(117, 92, 'green eggs and ham', 'dr. seuss', True)],
#   []),
#  (95,
#   91,
#   'captain underpants and the perilous plot of professor poopypants',
#   'dav pilkey',
#   [(19,
#     19,
#     'captain underpants and the perilous plot of professor poopypants',
#     'dav pilkey',
#     True),
#    (14,
#     14,
#     'captain underpants and the invasion of the incredibly naughty cafeteria ladies from outer space ..',
#     'dav pilkey',
#     True),
#    (8,
#     8,
#     'captain underpants and the preposterous plight of the purple potty people (captain underpants)',
#     'dav pilkey',
#     True),
#    (8,
#     8,
#     'captain underpants and the wrath of the wicked wedgie woman',
#     'dav pilkey',
#     True),
#    (7,
#     7,
#     'captain underpants and the big, bad battle of the bionic booger boy',
#     'dav pilkey',
#     True),
#    (6,
#     6,
#     'captain underpants and the terrifying return of tippy tinkletrousers',
#     'dav pilkey',
#     True),
#    (4,
#     4,
#     'captain underpants and the big, bad battle of the bionic booger boy, part 2',
#     'dav pilkey',
#     True),
#    (1,
#     1,
#     'captain underpants and the wrath of the wicked wedgie women',
#     'dav pilkey',
#     True)],
#   [(5,
#     5,
#     'captain underpants and the revolting revenge of the radioactive robo-boxers',
#     'dav pilkey',
#     False),
#    (5,
#     5,
#     'captain underpants and the sensational saga of sir stinks-a-lot',
#     'dav pilkey',
#     False),
#    (3,
#     3,
#     'captain underpants and the tyrannical retaliation of the turbo toilet 2000',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the big bad battle of the bionic booger boy part 1: the night of the nasty nostril nuggets',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the big bad battle of the bionic booger boy part 1: the night of the nasty nostril nuggets',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the big, bad battle of the bionic booger boy battle - part 1: the night of the nasty nostril nuggets',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the big, bad battle of the bionic booger boy battle part two',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the big, bad battle of the bionic booger boy, part 1: the night of the nasty nostril nuggets (captain underpants #6)',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the big, bad battle of the bionic booger boy, part 2: the revenge of the ridiculous robo-boogers',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the preposterous plight of the purple potty people - book 8',
#     'dav pikley',
#     False),
#    (1,
#     1,
#     'captain underpants and the revenge of the wicked wedgie women',
#     'dav pikley',
#     False),
#    (5,
#     1,
#     'captain underpants and the sensational saga of sir stinks a lot',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the terrifying return of tippy tinkle trousers',
#     '',
#     False),
#    (1,
#     1,
#     'captainunderpants and the wrath of the wicked wedgie woman',
#     'dav pilkey',
#     False)]),
#  (166,
#   89,
#   'chicka chicka boom boom',
#   'martin, bill',
#   [(77, 42, 'chicka chicka boom boom', 'martin, bill', True),
#    (29,
#     23,
#     'chicka chicka boom boom',
#     'bill martin jr. & john archamba',
#     True),
#    (9, 9, 'chicka chicka abc', 'martin, bill', True),
#    (9, 5, 'chicka chicka 1 2 3', 'bill martin jr.', True),
#    (6,
#     3,
#     'chicka chicka boom boom',
#     'bill martin jr, john archambault',
#     True)],
#   [(32, 4, 'chicka chicka 123', 'bill martin', False),
#    (2, 1, 'chicka chicka boo', '', False),
#    (1,
#     1,
#     'chicka chicka boom boom',
#     'by bill martin john jrarchambault',
#     False),
#    (1, 1, 'chicka chicka boom boom', 'by bill martin jr', False)]),
#  (173,
#   78,
#   'brown bear, brown bear, what do you see?',
#   'bill martin, jr.',
#   [(40,
#     28,
#     'brown bear, brown bear, what do you see?',
#     'bill martin, jr.',
#     True),
#    (84, 18, 'brown bear, brown bear elt pack', 'bill martin', True)],
#   [(28, 14, 'brown bear, brown bear, what do you see?', 'bill martin', False),
#    (8, 6, 'brown bear brown bear what do you see?', 'bill martin', False),
#    (3, 3, 'baby bear baby bear who do you see?', 'bill martin', False),
#    (3, 3, 'baby bear, baby bear, what do you see?', 'martin, bill', False),
#    (3, 2, 'baby bear, baby bear, what do you see?', 'bill martin jr.', False),
#    (2, 2, 'brown bear, brown bear what do you see?', 'bill martin jr.', False),
#    (1,
#     1,
#     'brown bear brown bear what do you see',
#     'by bill martin jr. eric carle',
#     False),
#    (1,
#     1,
#     'brown bear, brown bear, what do you see?',
#     'bill martin jr',
#     False)]),
#  (121,
#   74,
#   "don't let the pigeon drive the bus!",
#   'mo willems',
#   [(64, 35, "don't let the pigeon drive the bus!", 'mo willems', True),
#    (24, 18, "don't let the pigeon stay up late!", 'mo willems', True)],
#   [(19, 9, "don't let the pigeon drive the bus!", 'mo willems', False),
#    (10, 8, "don't let the pigeon stay up late!", 'mo willems', False),
#    (2, 2, "don't let the pigeons stay up lat", 'mo willems', False),
#    (1, 1, '"the pigeon wants a puppy', 'mo willems', False),
#    (1,
#     1,
#     "don't let the pigeon finish this mini activity book",
#     'mo willems',
#     False)])]

# %% [markdown]
# ## Phase 3
#
# FuzzySet is really fast, but there are some matches it just can't catch.  After doing all the clustering we can with fuzzyset, we'll fill in the gaps using the much slower method of iterating through each pair of clusters and comaparing them with fuzzywuzzy, and merging the clusters that match using the c.engulf() function.
#
# This step would be far too slow if run on all books, so cutoffs on the number of iterations are included.

# %%
l = fd.as_sorted_list()
i=0
loops = 0
maxloops = 10000
while i < min(len(l), 1000) and loops < maxloops:

    j=i+1
    while j < min(len(l), 1000) and loops < maxloops:
        
        if is_match(l[i].get_title(), l[i].get_author(),
                    l[j],
                    False):
            #engulf cluster j into cluster i
            #then remove cluster j from the list
            #dont increment j as next cluster will now be in jth position
            if DEBUG_FUZZY_MATCHING:
                print(" ")
                print("merging clusters:")
                print(" ")
                print(repr(l[i].rep(v=False)))
                print(" ")
                print(repr(l[j].rep(v=False)))
                print(" ")
            l[i].engulf(l[j])
            l.pop(j)
        else:
            j = j+1
        
        loops = loops + 1
    
    i = i+1

l = sort_cluster_list(l)
# Out:
#
# merging clusters:
#
# (289, 195, 'curious george', 'h. a. rey')
#
# (58, 48, 'curious george goes to a chocolate factory', 'h. a. rey')
#
#
# merging clusters:
#
# (347, 243, 'curious george', 'h. a. rey')
#
# (49, 32, 'curious george at the baseball game', 'h.a. and margret rey')
#
#
# merging clusters:
#
# (396, 275, 'curious george', 'h. a. rey')
#
# (30, 24, 'curious george flies a kite (curious george)', 'margret rey, h. a. rey')
#
#
# merging clusters:
#
# (426, 299, 'curious george', 'h. a. rey')
#
# (24, 22, 'curious george goes to a costume party', 'margaret and h. a. rey')
#
#
# merging clusters:
#
# (450, 321, 'curious george', 'h. a. rey')
#
# (8, 6, "curious george: plumber's helper", 'h.a. rey')
#
#
# merging clusters:
#
# (142, 138, 'captain underpants', 'dav pilkey')
#
# (47, 47, 'captain underpants', 'dav pilkey')
#
#
# merging clusters:
#
# (152, 135, 'fancy nancy', "jane o'connor")
#
# (12, 12, 'fancy nancy best reading buddies', '')
#
#
# merging clusters:
#
# (164, 147, 'fancy nancy', "jane o'connor")
#
# (9, 8, 'fancy nancy potpourri of books: poison ivy expert, the show must go on, spectacular spectacles', "jane o'connor")
#
#
# merging clusters:
#
# (173, 155, 'fancy nancy', "jane o'connor")
#
# (5, 5, 'fancy nancy too many tutus', 'robin preiss glasser')
#
#
# merging clusters:
#
# (178, 160, 'fancy nancy', "jane o'connor")
#
# (5, 5, 'fancy nancy and the super secret surprise party', 'jane o connor')
#
#
# merging clusters:
#
# (89, 68, 'big nate', 'lincoln peirce')
#
# (7, 7, 'big nate welcome to my world', '')
#
#
# merging clusters:
#
# (71, 67, 'clifford the big red dog', 'norman bridwell')
#
# (4, 4, "clifford's family", 'norman bridell')
#
#
# merging clusters:
#
# (75, 71, 'clifford the big red dog', 'norman bridwell')
#
# (4, 4, 'clifford goes to kindergarten', 'norman bridwell')
#
#
# merging clusters:
#
# (79, 75, 'clifford the big red dog', 'norman bridwell')
#
# (4, 4, "clifford's first day of school", 'norman bridell')
#
#
# merging clusters:
#
# (86, 64, 'bad kitty vs uncle murray', 'nick bruel')
#
# (6, 6, 'bad kitty does not like video games', '')
#
#
# merging clusters:
#
# (86, 64, 'hop on pop', 'dr. seuss')
#
# (7, 6, 'in a people house', 'dr. seuss')
#
#
# merging clusters:
#
# (98, 60, 'biscuit goes to school', 'alyssa satin capucilli')
#
# (8, 6, 'biscuit feeds the pets', 'capucilli, alyssa')
#
#
# merging clusters:
#
# (88, 56, 'i am going!', 'mo willems')
#
# (18, 16, 'i am going!', 'mo willems')
#
#
# merging clusters:
#
# (106, 72, 'i am going!', 'mo willems')
#
# (12, 11, 'a big guy took my ball!', 'mo willems')
#
#
# merging clusters:
#
# (75, 55, 'bears in the night', 'stan berenstain')
#
# (11, 11, 'bears in the night', 'stan berenstain')
#
#
# merging clusters:
#
# (86, 66, 'bears in the night', 'stan berenstain')
#
# (20, 8, 'berenstain bears visit the fire station', 'jan berenstain')
#
#
# merging clusters:
#
# (50, 49, 'dog man', 'dav pilkey')
#
# (17, 17, 'big dog and little dog going for a walk', 'dav pilkey')
#
#
# merging clusters:
#
# (48, 48, 'cara the camp fairy', 'daisy meadows')
#
# (12, 12, 'bella the bunny fairy', 'daisy meadows')
#
#
# merging clusters:
#
# (60, 60, 'cara the camp fairy', 'daisy meadows')
#
# (4, 4, 'eleanor the snow white fairy', 'daisy meadows')
#
#
# merging clusters:
#
# (64, 64, 'cara the camp fairy', 'daisy meadows')
#
# (3, 3, 'abigail the breeze fairy (weather fairies)', 'daisy meadows')
#
#
# merging clusters:
#
# (61, 48, 'daniel gets scared', 'maggie testa')
#
# (12, 12, 'daniel gets scared', 'maggie testa')
#
#
# merging clusters:
#
# (73, 60, 'daniel gets scared', 'maggie testa')
#
# (10, 10, "daniel tiger's neighborhood: daniel visits the library", 'maggie testa')
#
#
# merging clusters:
#
# (83, 70, 'daniel gets scared', 'maggie testa')
#
# (8, 7, 'daniel visits the library', 'maggie testa')
#
#
# merging clusters:
#
# (91, 77, 'daniel gets scared', 'maggie testa')
#
# (8, 6, 'daniel feels left out', 'maggie testa')
#
#
# merging clusters:
#
# (65, 47, 'how do dinosaurs say happy birthday?', 'jane yolen')
#
# (4, 4, 'como dan las buenas noches los dinosaurios? / how do dinosaurs say goodnight?', 'jane yolen')
#
#
# merging clusters:
#
# (45, 43, 'dork diaries', 'rachel renee russell')
#
# (23, 21, 'dork diaries', 'rachel renee russell')
#
#
# merging clusters:
#
# (64, 42, 'babymouse: camp babymouse', 'jennifer l. holm')
#
# (26, 5, 'baby mouse', 'jennifer l. holm')
#
#
# merging clusters:
#
# (49, 40, 'duck, duck, goose', 'tad hills')
#
# (22, 16, 'duck & goose, here comes the easter bunny!', 'tad hills')
#
#
# merging clusters:
#
# (40, 37, 'dr.seuss abc (dr seuss)', 'dr. seuss')
#
# (14, 14, "dr. suess's abc", 'dr. seuss')
#
#
# merging clusters:
#
# (51, 37, 'i can read with my eyes shut', 'dr. seuss')
#
# (15, 12, 'i am not going to get up today!', 'dr. seuss')
#
#
# merging clusters:
#
# (66, 49, 'i can read with my eyes shut', 'dr. seuss')
#
# (10, 6, 'cat in the hat comes back, the', 'dr. seuss')
#
#
# merging clusters:
#
# (36, 36, 'adventures in odyssey-opposite day', '')
#
# (4, 4, 'adventures in colors and shapes', 'walt disney productions')
#
#
# merging clusters:
#
# (52, 34, 'bear wants more', 'karma wilson')
#
# (20, 16, 'bear snores on', 'karma wilson')
#
#
# merging clusters:
#
# (38, 32, 'henry and mudge and the funny lunch', 'cynthia rylant')
#
# (12, 10, 'henry and mudge', 'cynthia rylant')
#
#
# merging clusters:
#
# (31, 31, 'attack on titan attack on titan', 'hajime isayama')
#
# (12, 12, 'attack on tital 15', '')
#
#
# merging clusters:
#
# (33, 25, 'a wrinkle in time', "madeleine l'engle")
#
# (6, 5, 'a wind in the door', "madeleine l'engle")
#
#
# merging clusters:
#
# (22, 22, 'cross fire', 'james patterson')
#
# (6, 6, 'i, alex cross', 'james patterson')
#
#
# merging clusters:
#
# (25, 22, 'fox in love', 'edward marshall')
#
# (6, 4, 'fox outfoxed', 'james marshall')
#
#
# merging clusters:
#
# (64, 21, 'bob books set 5- long vowels', 'bobby lynn maslen')
#
# (48, 7, 'bob books set 5- long vowels', 'bobby lynn maslen')
#
#
# merging clusters:
#
# (20, 20, 'a to z mysteries', 'ron roy')
#
# (10, 10, 'a-z mysteries: the canary caper', 'ron roy')
#
#
# merging clusters:
#
# (26, 20, 'daniel and the nutcracker', 'angela c santomero')
#
# (11, 10, "daniel's first sleepover", 'angela santomero')
#
#
# merging clusters:
#
# (38, 19, 'dinoblock', 'christopher franceschelli')
#
# (15, 6, 'countablock', 'christopher franceschelli')
#
#
# merging clusters:
#
# (53, 25, 'dinoblock', 'christopher franceschelli')
#
# (15, 6, 'dinoblock', 'christopher franceschelli')
#
#
# merging clusters:
#
# (24, 19, "ballet cat: what's your favorite favorite", 'bob shea')
#
# (9, 9, 'ballet cat : the totally secret secret', 'bob shea')
#
#
# merging clusters:
#
# (32, 19, 'cars go', 'steve light')
#
# (13, 7, 'diggers go', 'steve light')
#
#
# merging clusters:
#
# (18, 18, 'bleach, volume 2', 'tite kubo')
#
# (4, 4, 'bleach volume 54', '')
#
#
# merging clusters:
#
# (17, 17, 'fairy tail 1 (fairy tail)', 'hiro mashima')
#
# (7, 7, 'fairy tail 50', '')
#
#
# merging clusters:
#
# (27, 17, 'daniel tiger', 'farranmc doogle')
#
# (6, 5, 'daniel tiger', '')
#
#
# merging clusters:
#
# (33, 22, 'daniel tiger', 'farranmc doogle')
#
# (11, 4, 'daniel tiger big enough to help', '')
#
#
# merging clusters:
#
# (16, 16, 'death on the nile', 'agatha christie')
#
# (4, 4, 'appointment with death', 'agatha christie')
#
#
# merging clusters:
#
# (20, 20, 'death on the nile', 'agatha christie')
#
# (4, 4, 'death in the clouds (hercule poirot)', 'agatha christie')
#
#
# merging clusters:
#
# (35, 16, 'apple picking day!', 'candice ransom')
#
# (8, 5, 'caillou goes apple picking', '')
#
#
# merging clusters:
#
# (16, 14, 'an elephant and piggy biggie', 'mo williams')
#
# (7, 6, 'an elephant and piggy biggie', 'mo williams')
#
#
# merging clusters:
#
# (14, 13, 'death of a gossip', 'm. c. beaton')
#
# (3, 3, 'agatha raisin and the quiche of death', 'm. c. beaton')
#
#
# merging clusters:
#
# (13, 13, 'build dogs, build', 'james horvath')
#
# (5, 5, 'dig, dogs, dig: a construction tail', 'james horvath')
#
#
# merging clusters:
#
# (12, 12, 'buenas noches, búho', 'sandra boynton')
#
# (4, 4, 'buenas noches a todos / the going to bed book', 'sandra boynton')
#
#
# merging clusters:
#
# (12, 12, 'disney planes wings around the globe', 'bill scollon')
#
# (4, 4, 'disney planes look and find', '')
#
#
# merging clusters:
#
# (11, 11, 'geronimo stilton 39 singing sensation', 'geronimo stilton')
#
# (3, 3, 'cheese-colored camper (geronimo stilton)', 'geronimo stilton')
#
#
# merging clusters:
#
# (11, 10, 'and to think that i saw it on mulberry street', 'dr. seuss')
#
# (4, 3, 'bartholomew and the oobleck', 'dr. seuss')
#
#
# merging clusters:
#
# (10, 10, 'feathers and hair: what animals wear', 'jennifer ward')
#
# (4, 4, 'animal babies in towns and cities', 'jennifer schofield')
#
#
# merging clusters:
#
# (11, 9, 'horns to toes and in between', 'sandra boynton')
#
# (6, 4, 'horns to toes and in between', 'sandra boynton')
#
#
# merging clusters:
#
# (9, 9, 'd.w. goes to preschool', 'marc tolon brown')
#
# (3, 3, "d.w.'s lost blankie", 'marc tolon brown')
#
#
# merging clusters:
#
# (11, 9, 'animals =', 'eric carle')
#
# (6, 4, 'animals =', 'eric carle')
#
#
# merging clusters:
#
# (8, 8, 'cooking light', 'heather averett')
#
# (4, 4, 'cooking light magazine', '')
#
#
# merging clusters:
#
# (8, 8, 'i am too absolutely small for school', 'lauren child')
#
# (4, 4, 'absolutely one thing: featuring charlie and lola', 'lauren child')
#
#
# merging clusters:
#
# (8, 8, '5minute disney pixar stories', 'disney press')
#
# (3, 3, '5minute disney pixar stories', 'disney press')
#
#
# merging clusters:
#
# (8, 8, 'ever after high: the storybook of legends', 'shannon hale')
#
# (3, 3, 'a wonderlandiful world (ever after high)', 'shannon hale')
#
#
# merging clusters:
#
# (7, 7, 'a feast for crows', 'george r. r. martin')
#
# (3, 3, 'a storm of swords', 'george r. r. martin')
#
#
# merging clusters:
#
# (10, 7, 'caillou rides on a plane', 'roger harvey')
#
# (5, 3, 'caillou rides on a plane', 'roger harvey')

# %%
replist = []
for c in l: replist.append(c.rep(v=True))
    
replist[:10]
# Out:
# [(412,
#   378,
#   "harry potter and the sorcerer's stone",
#   'j. k. rowling',
#   [(99, 87, "harry potter and the sorcerer's stone", 'j. k. rowling', True),
#    (60, 59, 'harry potter and the chamber of secrets', 'j. k. rowling', True),
#    (61, 54, 'harry potter and the goblet of fire', 'j. k. rowling', True),
#    (48,
#     44,
#     'harry potter and the order of the phoenix',
#     'j. k. rowling',
#     True),
#    (42, 40, 'harry potter and the prisoner of azkaban', 'j. k. rowling', True),
#    (39, 38, 'harry potter and the half-blood prince', 'j. k. rowling', True),
#    (38, 31, 'harry potter and the deathly hallows', 'j. k. rowling', True),
#    (23, 23, 'harry potter and the cursed child', 'j. k. rowling', True),
#    (1, 1, "harry potter and the philosopher's stone", 'j. k. rowling', True),
#    (1, 1, 'harry potter, tome 3', 'j. k. rowling', True)],
#   []),
#  (458,
#   327,
#   'curious george',
#   'h. a. rey',
#   [(67, 18, 'curious george', 'h. a. rey', True),
#    (17, 17, 'curious george goes to a chocolate factory', 'h. a. rey', True),
#    (17, 17, 'curious george goes to a chocolate factory', 'h. a. rey', True),
#    (11, 11, 'curious george goes camping', 'h. a. rey', True),
#    (8, 6, 'curious george rides a bike', 'h. a. rey', True),
#    (9, 6, 'curious george at the baseball game', 'h.a. and margret rey', True),
#    (9, 6, 'curious george at the baseball game', 'h.a. and margret rey', True),
#    (5, 5, 'curious george and the hot air balloon', 'h. a. rey', True),
#    (5,
#     5,
#     'curious george and the pizza',
#     'margret rey, alan j. shalleck',
#     True),
#    (5, 5, 'curious george and the hot air balloon', 'h. a. rey', True),
#    (5,
#     5,
#     'curious george and the pizza',
#     'margret rey, alan j. shalleck',
#     True),
#    (3, 3, 'curious george gets a medal', 'h. a. rey', True),
#    (3, 3, 'curious george makes pancakes', 'h. a. rey', True),
#    (5,
#     3,
#     'curious george flies a kite (curious george)',
#     'margret rey, h. a. rey',
#     True),
#    (5,
#     3,
#     'curious george flies a kite (curious george)',
#     'margret rey, h. a. rey',
#     True),
#    (2, 2, 'curious george goes to a costume party', 'h. a. rey', True),
#    (3, 2, 'curious george goes to the beach', 'h. a. rey', True),
#    (2, 2, 'curious george at the aquarium', 'h.a. and margret rey', True),
#    (8, 2, 'curious george flies a kite', 'margret rey', True),
#    (2,
#     2,
#     'curious george goes to the hospital',
#     'h. a. rey, margret rey',
#     True),
#    (2, 2, 'curious george visits the zoo', 'margret rey', True),
#    (2, 2, "curious george's dinosaur discovery", 'h.a. and margret rey', True),
#    (2,
#     2,
#     'curious george and the birthday surprise',
#     'h.a. and margret rey, margret rey, h.a. rey',
#     True),
#    (2, 2, 'curious george goes to a costume party', 'h. a. rey', True),
#    (3, 2, 'curious george goes to the beach', 'h. a. rey', True),
#    (2, 2, 'curious george at the aquarium', 'h.a. and margret rey', True),
#    (8, 2, 'curious george flies a kite', 'margret rey', True),
#    (2,
#     2,
#     'curious george goes to the hospital',
#     'h. a. rey, margret rey',
#     True),
#    (2, 2, 'curious george visits the zoo', 'margret rey', True),
#    (2, 2, "curious george's dinosaur discovery", 'h.a. and margret rey', True),
#    (2,
#     2,
#     'curious george and the birthday surprise',
#     'h.a. and margret rey, margret rey, h.a. rey',
#     True),
#    (1, 1, 'curious george and the bunny', '', True),
#    (1, 1, 'curious george and the dinosaur', '', True),
#    (1, 1, 'curious george and the dump truck.', '', True),
#    (1, 1, 'curious george goes to a movie.', '', True),
#    (1, 1, 'curious george in the snow', '', True),
#    (1, 1, 'curious george plays baseball', '', True),
#    (7, 1, "curious george's opposites", 'h. a. rey', True),
#    (1, 1, 'curious george and the puppies', 'h. a. rey', True),
#    (2, 1, 'curious george and the rocket', 'h. a. rey', True),
#    (1, 1, 'curious george feeds the animals', 'h. a. rey', True),
#    (1, 1, 'curious george learns to count from 1 to 100', 'h. a. rey', True),
#    (1, 1, 'curious george saves his pennies', 'h. a. rey', True),
#    (1, 1, 'curious george and the dump truck.', 'margret rey', True),
#    (1, 1, 'curious george and the pizza party', 'margret rey', True),
#    (1, 1, 'curious george builds a home', 'h.a. and margret rey', True),
#    (1, 1, 'curious george feeds the animals', 'h. a. rey, margret rey', True),
#    (1,
#     1,
#     'curious george goes to a chocolate factory',
#     'h.a. and margret rey',
#     True),
#    (1,
#     1,
#     'curious george goes to a costume party',
#     'h.a. and margret rey',
#     True),
#    (9, 1, 'curious george goes to the hospital', 'margret rey', True),
#    (1, 1, 'curious george takes a trip', 'h.a. and margret rey', True),
#    (1,
#     1,
#     "curious george's first words at the zoo",
#     'h.a. and margret rey',
#     True),
#    (1,
#     1,
#     'curious george goes to a costume party',
#     'h. a. rey, margret rey, vipah interactive',
#     True),
#    (1, 1, 'curious george and the puppies', 'h. a. rey', True),
#    (2, 1, 'curious george and the rocket', 'h. a. rey', True),
#    (1, 1, 'curious george feeds the animals', 'h. a. rey', True),
#    (1, 1, 'curious george learns to count from 1 to 100', 'h. a. rey', True),
#    (1, 1, 'curious george saves his pennies', 'h. a. rey', True),
#    (1, 1, 'curious george and the dump truck.', 'margret rey', True),
#    (1, 1, 'curious george and the pizza party', 'margret rey', True),
#    (1, 1, 'curious george builds a home', 'h.a. and margret rey', True),
#    (1, 1, 'curious george feeds the animals', 'h. a. rey, margret rey', True),
#    (1,
#     1,
#     'curious george goes to a chocolate factory',
#     'h.a. and margret rey',
#     True),
#    (1,
#     1,
#     'curious george goes to a costume party',
#     'h.a. and margret rey',
#     True),
#    (9, 1, 'curious george goes to the hospital', 'margret rey', True),
#    (1, 1, 'curious george takes a trip', 'h.a. and margret rey', True),
#    (1,
#     1,
#     "curious george's first words at the zoo",
#     'h.a. and margret rey',
#     True),
#    (1,
#     1,
#     'curious george goes to a costume party',
#     'h. a. rey, margret rey, vipah interactive',
#     True)],
#   [(4, 4, 'curious george and the bunny', 'h.a. rey', False),
#    (4,
#     4,
#     'curious george and the chocolate factory',
#     'margaret and h a rey',
#     False),
#    (4,
#     4,
#     'curious george goes to the chocolate factory',
#     "margaret and h.a rey's",
#     False),
#    (4,
#     4,
#     'curious george and the chocolate factory',
#     'margaret and h a rey',
#     False),
#    (4,
#     4,
#     'curious george goes to the chocolate factory',
#     "margaret and h.a rey's",
#     False),
#    (3,
#     3,
#     'curious george goes to a chocolate factory',
#     'margaret and h.a. rey',
#     False),
#    (6, 3, 'curious george visits a toy store', 'margret & h.a. rey', False),
#    (3,
#     3,
#     'curious george goes to a costume party',
#     'margaret and h. a. rey',
#     False),
#    (3,
#     3,
#     'curious george goes to a costume party',
#     'margaret and h.a. rey',
#     False),
#    (3, 3, 'curious george in the snow', 'margaret and h.a. rey', False),
#    (5, 3, "curious george: plumber's helper", 'h.a. rey', False),
#    (3,
#     3,
#     'curious george goes to a chocolate factory',
#     'margaret and h.a. rey',
#     False),
#    (6, 3, 'curious george visits a toy store', 'margret & h.a. rey', False),
#    (3,
#     3,
#     'curious george goes to a costume party',
#     'margaret and h. a. rey',
#     False),
#    (3,
#     3,
#     'curious george goes to a costume party',
#     'margaret and h.a. rey',
#     False),
#    (3, 3, 'curious george in the snow', 'margaret and h.a. rey', False),
#    (5, 3, "curious george: plumber's helper", 'h.a. rey', False),
#    (2, 2, 'curious george and the dinosaur', 'margaret and h.a. rey', False),
#    (2,
#     2,
#     'curious george and the hot air balloon',
#     'margaret and h.a. rey',
#     False),
#    (2,
#     2,
#     'curious george five minute stories',
#     'margaret and h.a. rey',
#     False),
#    (2, 2, 'curious george goes to a movie', 'margaret and h.a. rey', False),
#    (2, 2, 'curious george goes to a movie', 'rey, margret & ha', False),
#    (2, 2, 'curious george and the dinosaur', 'margaret and h.a. rey', False),
#    (2,
#     2,
#     'curious george and the hot air balloon',
#     'margaret and h.a. rey',
#     False),
#    (2,
#     2,
#     'curious george five minute stories',
#     'margaret and h.a. rey',
#     False),
#    (2, 2, 'curious george goes to a movie', 'margaret and h.a. rey', False),
#    (2, 2, 'curious george goes to a movie', 'rey, margret & ha', False),
#    (1, 1, 'curious george 123', '', False),
#    (1, 1, 'curious george and the sleepover', '', False),
#    (1, 1, 'curious george at the aqarium', '', False),
#    (1, 1, 'curious george builds an igloo', '', False),
#    (1, 1, 'curious george discovers the senses', '', False),
#    (1, 1, 'curious george farm to table', '', False),
#    (1, 1, 'curious george good night book', '', False),
#    (1, 1, 'curious george goodnight book', '', False),
#    (1, 1, 'curious george in the snow', 'h.a. rey', False),
#    (1, 1, 'curious george pinata party', '', False),
#    (1, 1, 'curious george plants a tree', 'h. a. rey', False),
#    (1, 1, 'curious george goes camping', 'margaret and h.a. rey', False),
#    (1, 1, 'curious george and the pizza party', 'h. a. rey', False),
#    (1, 1, 'curious george goes camping', 'margaret and h.a. rey', False),
#    (1, 1, 'curious george goes to an ice cream shop', 'h.l. rey', False),
#    (3, 1, 'curious george goes to the library', 'h.a. ray', False),
#    (7, 1, "curious george's 1 to 10 and back", 'h. a. rey', False),
#    (1, 1, 'curious george and the baseball game', '', False),
#    (1, 1, 'curious george at the beach', 'margret rey', False),
#    (1, 1, 'curios george visits a toy store', 'margret & h.a. rey', False),
#    (1,
#     1,
#     'curious george and the birthday surprise',
#     'margaret and h a rey',
#     False),
#    (2, 1, 'curious george and the dump truck', 'margret & h.a. rey', False),
#    (1, 1, 'curious george and the dump truck', 'margret and h.a. rey', False),
#    (1, 1, 'curious george and the dump truck', 'margret and h.a.rey', False),
#    (1, 1, 'curious george and the pizza', 'margret and h.a. rey', False),
#    (1, 1, 'curious george and the puppies', 'margaret & h.a. rey', False),
#    (1, 1, 'curious george and the puppies', 'margaret and h.a. rey', False),
#    (1, 1, 'curious george feeds the animals', 'margaret and h.a. rey', False),
#    (1, 1, 'curious george goes camping', 'margaret and ha rey', False),
#    (1, 1, 'curious george in the snow', 'margaret and h a rey', False),
#    (3, 1, 'curious george plants a tree', 'margaret & h.a. rey', False),
#    (1, 1, 'curious george plays baseball', 'margaret and h.a. rey', False),
#    (1, 1, 'curious george takes a job', 'margaret and h.a. rey', False),
#    (1, 1, 'curious george takes a train', 'margaret and h a rey', False),
#    (1, 1, 'curious george takes a train', "margret & h.a. rey's", False),
#    (1, 1, 'curious george visits the zoo', 'margret and h.a. rey', False),
#    (1,
#     1,
#     "curious george's first day of school",
#     'margaret and h.a. rey',
#     False),
#    (1, 1, 'curious george plants a tree', 'rey', False),
#    (1, 1, "curious george plumber's helper", 'h.a. rey', False),
#    (1, 1, 'curious george rain or shine', 'reyy', False),
#    (1, 1, 'curious george goes camping', 'margaret and h.a. rey', False),
#    (1, 1, 'curious george and the pizza party', 'h. a. rey', False),
#    (1, 1, 'curious george goes camping', 'margaret and h.a. rey', False),
#    (1, 1, 'curious george goes to an ice cream shop', 'h.l. rey', False),
#    (3, 1, 'curious george goes to the library', 'h.a. ray', False),
#    (7, 1, "curious george's 1 to 10 and back", 'h. a. rey', False),
#    (1, 1, 'curious george and the baseball game', '', False),
#    (1, 1, 'curious george at the beach', 'margret rey', False),
#    (1, 1, 'curios george visits a toy store', 'margret & h.a. rey', False),
#    (1,
#     1,
#     'curious george and the birthday surprise',
#     'margaret and h a rey',
#     False),
#    (2, 1, 'curious george and the dump truck', 'margret & h.a. rey', False),
#    (1, 1, 'curious george and the dump truck', 'margret and h.a. rey', False),
#    (1, 1, 'curious george and the dump truck', 'margret and h.a.rey', False),
#    (1, 1, 'curious george and the pizza', 'margret and h.a. rey', False),
#    (1, 1, 'curious george and the puppies', 'margaret & h.a. rey', False),
#    (1, 1, 'curious george and the puppies', 'margaret and h.a. rey', False),
#    (1, 1, 'curious george feeds the animals', 'margaret and h.a. rey', False),
#    (1, 1, 'curious george goes camping', 'margaret and ha rey', False),
#    (1, 1, 'curious george in the snow', 'margaret and h a rey', False),
#    (3, 1, 'curious george plants a tree', 'margaret & h.a. rey', False),
#    (1, 1, 'curious george plays baseball', 'margaret and h.a. rey', False),
#    (1, 1, 'curious george takes a job', 'margaret and h.a. rey', False),
#    (1, 1, 'curious george takes a train', 'margaret and h a rey', False),
#    (1, 1, 'curious george takes a train', "margret & h.a. rey's", False),
#    (1, 1, 'curious george visits the zoo', 'margret and h.a. rey', False),
#    (1,
#     1,
#     "curious george's first day of school",
#     'margaret and h.a. rey',
#     False),
#    (1, 1, 'curious george plants a tree', 'rey', False),
#    (1, 1, "curious george plumber's helper", 'h.a. rey', False),
#    (1, 1, 'curious george rain or shine', 'reyy', False)]),
#  (189,
#   185,
#   'captain underpants',
#   'dav pilkey',
#   [(21, 21, 'captain underpants', 'dav pilkey', True),
#    (21, 21, 'captain underpants', 'dav pilkey', True),
#    (19,
#     19,
#     'captain underpants and the perilous plot of professor poopypants',
#     'dav pilkey',
#     True),
#    (17,
#     17,
#     'captain underpants and the attack of the talking toilets',
#     'dav pilkey',
#     True),
#    (17,
#     17,
#     'captain underpants and the attack of the talking toilets',
#     'dav pilkey',
#     True),
#    (14,
#     14,
#     'captain underpants and the invasion of the incredibly naughty cafeteria ladies from outer space ..',
#     'dav pilkey',
#     True),
#    (8,
#     8,
#     'captain underpants and the preposterous plight of the purple potty people (captain underpants)',
#     'dav pilkey',
#     True),
#    (8,
#     8,
#     'captain underpants and the wrath of the wicked wedgie woman',
#     'dav pilkey',
#     True),
#    (7,
#     7,
#     'captain underpants and the big, bad battle of the bionic booger boy',
#     'dav pilkey',
#     True),
#    (6,
#     6,
#     'captain underpants and the terrifying return of tippy tinkletrousers',
#     'dav pilkey',
#     True),
#    (4,
#     4,
#     'captain underpants and the big, bad battle of the bionic booger boy, part 2',
#     'dav pilkey',
#     True),
#    (1,
#     1,
#     'captain underpants and the wrath of the wicked wedgie women',
#     'dav pilkey',
#     True),
#    (1, 1, 'captain underpants plush action doll, 8"', 'dav pilkey', True),
#    (1, 1, 'captain underpants plush action doll, 8"', 'dav pilkey', True)],
#   [(5,
#     5,
#     'captain underpants and the revolting revenge of the radioactive robo-boxers',
#     'dav pilkey',
#     False),
#    (5,
#     5,
#     'captain underpants and the sensational saga of sir stinks-a-lot',
#     'dav pilkey',
#     False),
#    (3,
#     3,
#     'captain underpants and the tyrannical retaliation of the turbo toilet 2000',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the big bad battle of the bionic booger boy part 1: the night of the nasty nostril nuggets',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the big bad battle of the bionic booger boy part 1: the night of the nasty nostril nuggets',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the big, bad battle of the bionic booger boy battle - part 1: the night of the nasty nostril nuggets',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the big, bad battle of the bionic booger boy battle part two',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the big, bad battle of the bionic booger boy, part 1: the night of the nasty nostril nuggets (captain underpants #6)',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the big, bad battle of the bionic booger boy, part 2: the revenge of the ridiculous robo-boogers',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the preposterous plight of the purple potty people - book 8',
#     'dav pikley',
#     False),
#    (1,
#     1,
#     'captain underpants and the revenge of the wicked wedgie women',
#     'dav pikley',
#     False),
#    (5,
#     1,
#     'captain underpants and the sensational saga of sir stinks a lot',
#     'dav pilkey',
#     False),
#    (1,
#     1,
#     'captain underpants and the terrifying return of tippy tinkle trousers',
#     '',
#     False),
#    (1,
#     1,
#     'captainunderpants and the wrath of the wicked wedgie woman',
#     'dav pilkey',
#     False),
#    (1, 1, 'captain underpaitns 12', 'dav pilkey', False),
#    (1, 1, 'captain underpants 10', 'dav pilkey', False),
#    (1, 1, 'captain underpants 11', 'dav pilkey', False),
#    (1, 1, 'captain underpants 6', 'dav pilkey', False),
#    (1, 1, 'captain underpants 7', 'dav pilkey', False),
#    (1, 1, 'captain underpants 9', 'dav pilkey', False),
#    (1, 1, 'captain underpants book 7', 'dav pilkey', False),
#    (1, 1, 'captin underpants', 'div pilkey', False),
#    (1, 1, 'captain underpaitns 12', 'dav pilkey', False),
#    (1, 1, 'captain underpants 10', 'dav pilkey', False),
#    (1, 1, 'captain underpants 11', 'dav pilkey', False),
#    (1, 1, 'captain underpants 6', 'dav pilkey', False),
#    (1, 1, 'captain underpants 7', 'dav pilkey', False),
#    (1, 1, 'captain underpants 9', 'dav pilkey', False),
#    (1, 1, 'captain underpants book 7', 'dav pilkey', False),
#    (1, 1, 'captin underpants', 'div pilkey', False)]),
#  (183,
#   165,
#   'fancy nancy',
#   "jane o'connor",
#   [(17, 15, 'fancy nancy', "jane o'connor", True),
#    (9,
#     8,
#     'fancy nancy potpourri of books: poison ivy expert, the show must go on, spectacular spectacles',
#     "jane o'connor",
#     True),
#    (9,
#     8,
#     'fancy nancy potpourri of books: poison ivy expert, the show must go on, spectacular spectacles',
#     "jane o'connor",
#     True),
#    (7, 6, 'fancy nancy and the mean girl', "jane o'connor", True),
#    (9, 6, 'fancy nancy and the mermaid ballet', "jane o'connor", True),
#    (4,
#     4,
#     'fancy nancy and the fabulous fashion boutique',
#     "jane o'connor",
#     True),
#    (4, 4, 'fancy nancy at the museum', "jane o'connor", True),
#    (4, 4, 'fancy nancy sees stars', "jane o'connor", True),
#    (4, 3, 'fancy nancy : bonjour, butterfly', "jane o'connor", True),
#    (3, 3, 'fancy nancy and the delectable cupcakes', "jane o'connor", True),
#    (3, 3, 'fancy nancy and the too-loose tooth', "jane o'connor", True),
#    (2, 2, 'fancy nancy aspiring artist', "jane o'connor", True),
#    (3, 2, 'fancy nancy fanciest doll in the universe', "jane o'connor", True),
#    (2, 2, 'fancy nancy just my luck', "jane o'connor", True),
#    (2, 2, "fancy nancy: hair dos and hair don'ts", "jane o'connor", True),
#    (1, 1, 'fancy nancy and the boy from paris', "jane o'connor", True),
#    (1, 1, 'fancy nancy and the late, late, late night', "jane o'connor", True),
#    (1, 1, 'fancy nancy, poison ivy expert', "jane o'connor", True),
#    (1, 1, 'fancy nancy too many tutus', 'robin preiss glasser', True),
#    (1, 1, 'fancy nancy too many tutus', 'robin preiss glasser', True)],
#   [(3, 3, 'fancy nancy peanut butter and jellyfish', "jane o'connor", False),
#    (5, 3, 'fancy nancy tea parties', "jane o'connor", False),
#    (2, 2, 'fancy nancy best reading buddies', "jane o'connor", False),
#    (3, 2, 'fancy nancy every day is earth day', "jane o'connor", False),
#    (2, 2, 'fancy nancy explorer extraodinaire', "jane o'connor", False),
#    (3, 2, 'fancy nancy my family history', "jane o'connor", False),
#    (2, 2, 'fancy nancy tea party', "jane o'connor", False),
#    (2, 2, "fancy nancy: ooh la la it's beauty day", "jane o'connor", False),
#    (2, 2, 'fancy nancy best reading buddies', '', False),
#    (2, 2, 'fancy nancy: tea parties', '', False),
#    (2,
#     2,
#     "fancy nancy's elegant easter",
#     "jane o'connor and robin preis-glasser",
#     False),
#    (2, 2, 'fancy nancy best reading buddies', '', False),
#    (2, 2, 'fancy nancy: tea parties', '', False),
#    (2,
#     2,
#     "fancy nancy's elegant easter",
#     "jane o'connor and robin preis-glasser",
#     False),
#    (2, 1, 'fancy nancy the 100th day of school', 'jane o, connor', False),
#    (1, 1, 'fancy nancy : just my luck!', "o'connor, jane", False),
#    (1, 1, 'fancy nancy and hte posh puppy', '', False),
#    (1, 1, 'fancy nancy apples galore', "jane o'connor", False),
#    (2, 1, 'fancy nancy apples galore!', "jane o'connor", False),
#    (1, 1, 'fancy nancy apples galore!', "o'connor, jane", False),
#    (1, 1, 'fancy nancy backwards day', "jane o'connor", False),
#    (1, 1, 'fancy nancy backwards day', 'jane o?connor', False),
#    (1, 1, 'fancy nancy best reading buddies', 'jane o, connor', False),
#    (1, 1, 'fancy nancy explorer extraordinaire', "jane o'connor", False),
#    (1, 1, 'fancy nancy fancy day in room 1-a', "jane o'connor", False),
#    (1, 1, 'fancy nancy fancy day in room 1-a', 'jane o?connor', False),
#    (1, 1, 'fancy nancy it,s backward day', 'jane o, connor', False),
#    (1, 1, 'fancy nancy my family history', 'jane o, connor', False),
#    (1, 1, 'fancy nancy my family history', 'jane o?connor', False),
#    (1, 1, 'fancy nancy pajama day', "jane o'connor", False),
#    (1, 1, 'fancy nancy peanut and jelly fish', "jane o'connor", False),
#    (2, 1, 'fancy nancy spectacular spctacles', 'jane o, connor', False),
#    (1, 1, 'fancy nancy splendid speller', 'jane o, connor', False),
#    (1, 1, 'fancy nancy the 100th day of school', 'jane o connor', False),
#    (1, 1, 'fancy nancy time for puppy school', 'jane o?connor', False),
#    (1, 1, 'fancy nancy, spectacular spectacles', "jane o'conner", False),
#    (1, 1, 'fancy nancy: budding ballerina', "jane o'connor", False),
#    (1, 1, 'fancy nancy: peanut butter and jellyfish', "jane o'conner", False),
#    (1, 1, 'fancy nancy: peanut butter and jellyfish', "jane o'connor", False),
#    (1, 1, 'fancy nancy: poison ivy expert', "jane o'connor", False),
#    (1, 1, 'fancy nancy: splendid speller', "jane o'conner", False),
#    (2, 1, 'fancy nancy: time for puppy school', "jane o'connor", False),
#    (1, 1, 'fancy nancy and the museum', '', False),
#    (1, 1, 'fancy nancy and the secret', '', False),
#    (1, 1, 'fancy nancy fancy day in room 1-a', '', False),
#    (1, 1, "fancy nancy it's backwards day", '', False),
#    (1, 1, 'fancy nancy poet extrodinaire', '', False),
#    (1, 1, 'fancy nancy saturday night sleepover', '', False),
#    (1, 1, 'fancy nancy splendid speller', '', False),
#    (1, 1, 'fancy nancyt', '', False),
#    (1,
#     1,
#     'fancy nancy ooo la la its beauty day',
#     "jane o'connor and robin press glasser",
#     False),
#    (1,
#     1,
#     'fancy nancy stellar stargazer',
#     "jane o'connor and robin press glasser",
#     False),
#    (1, 1, 'fancy nancy and the super secret surprise party', '', False),
#    (1, 1, 'fancy nancy and the 100th day of school', '', False),
#    (1, 1, 'fancy nancy super secret surprise party', 'jane o connor', False),
#    (1, 1, 'fancy nancy super secret surprise party', "jane o'connor", False),
#    (1, 1, 'fancy nancy super secret surprise party', 'jane o, connor', False),
#    (1, 1, 'fancy nancy and the museum', '', False),
#    (1, 1, 'fancy nancy and the secret', '', False),
#    (1, 1, 'fancy nancy fancy day in room 1-a', '', False),
#    (1, 1, "fancy nancy it's backwards day", '', False),
#    (1, 1, 'fancy nancy poet extrodinaire', '', False),
#    (1, 1, 'fancy nancy saturday night sleepover', '', False),
#    (1, 1, 'fancy nancy splendid speller', '', False),
#    (1, 1, 'fancy nancyt', '', False),
#    (1,
#     1,
#     'fancy nancy ooo la la its beauty day',
#     "jane o'connor and robin press glasser",
#     False),
#    (1,
#     1,
#     'fancy nancy stellar stargazer',
#     "jane o'connor and robin press glasser",
#     False),
#    (1, 1, 'fancy nancy and the super secret surprise party', '', False),
#    (1, 1, 'fancy nancy and the 100th day of school', '', False),
#    (1, 1, 'fancy nancy super secret surprise party', 'jane o connor', False),
#    (1, 1, 'fancy nancy super secret surprise party', "jane o'connor", False),
#    (1,
#     1,
#     'fancy nancy super secret surprise party',
#     'jane o, connor',
#     False)]),
#  (160,
#   156,
#   'diary of a wimpy kid',
#   'jeff kinney',
#   [(34, 34, 'diary of a wimpy kid', 'jeff kinney', True),
#    (5, 5, 'diary of a wimpy kid old school', 'jeff kinney', True),
#    (3, 3, 'diary of a wimpy kid : the long haul', '', True),
#    (2, 2, 'diary of a wimpy kid the third wheel', 'jeff kinney', True),
#    (1, 1, 'diary of a wimpy kid dog days', 'jeff kiney', True),
#    (1, 1, 'diary of a wimpy kid dog days', 'jeff kinney', True),
#    (1, 1, 'diary of a wimpy kid hard luck', '', True),
#    (1, 1, 'diary of a wimpy kid the last straw', 'jeff kinney', True)],
#   [(13, 13, 'diary of a wimpy kid: dog days', 'jeff kinney', False),
#    (11, 11, 'diary of a wimpy kid: long haul', 'jeff kinney', False),
#    (10, 10, 'diary of a wimpy kid: old school', 'jeff kinney', False),
#    (6, 6, 'diary of a wimpy kid: rodrick rules', 'jeff kinney', False),
#    (6, 6, 'diary of a wimpy kid: the ugly truth', 'jeff kinney', False),
#    (5, 5, 'diary of a wimpy kid: hard luck', 'jeff kinney', False),
#    (5, 5, 'diary of a wimpy kid: the last straw', 'jeff kinney', False),
#    (4, 4, 'diary of a wimpy kid: the long haul', 'jeff kinney', False),
#    (3, 3, 'diary of a wimpy kid double down', 'jeff kinney', False),
#    (3, 3, 'diary of a wimpy kid: cabin fever', 'jeff kinney', False),
#    (3, 3, 'diary of a wimpy kid: double down', 'jeff kinney', False),
#    (3, 3, 'diary of a wimpy kid: the third wheel', 'jeff kinney', False),
#    (2, 2, 'diary of a wimpy kid (series)', 'jeff kinney', False),
#    (2, 2, 'diary of a wimpy kid the ugly truth', '', False),
#    (6, 2, 'diary of a wimpy kid: double down', '', False),
#    (1, 1, 'diary of a wimpy kid 03', '', False),
#    (1, 1, 'diary of a wimpy kid 06', '', False),
#    (1, 1, 'diary of a wimpy kid 07', '', False),
#    (1, 1, 'diary of a wimpy kid 08', '', False),
#    (1, 1, 'diary of a wimpy kid 11', '', False),
#    (1, 1, 'diary of a wimpy kid # 7', '', False),
#    (1, 1, 'diary of a wimpy kid #2', '', False),
#    (1, 1, 'diary of a wimpy kid #7', '', False),
#    (1, 1, 'diary of a wimpy kid - double down', 'jeff kinney', False),
#    (1, 1, 'diary of a wimpy kid 2', '', False),
#    (1, 1, 'diary of a wimpy kid 6', '', False),
#    (1, 1, 'diary of a wimpy kid 7', '', False),
#    (1, 1, 'diary of a wimpy kid cabin fever', 'jeff kinny', False),
#    (1, 1, 'diary of a wimpy kid double down', '', False),
#    (1, 1, 'diary of a wimpy kid hard luck', 'jeff kinney', False),
#    (1, 1, 'diary of a wimpy kid the long hall', 'jeff kinne', False),
#    (1, 1, 'diary of a wimpy kid the long haul', 'jeff kinney', False),
#    (1, 1, 'diary of a wimpy kid: dog days', '', False),
#    (1, 1, 'diary of a wimpy kid: dog days', 'jeff kinney', False),
#    (1, 1, 'diary of a wimpy kid: cabin fever', '', False),
#    (1, 1, 'diary of a wimpy kid: dog days', '', False),
#    (1, 1, 'diary of a wimpy kid: double', 'jeff kinney', False),
#    (1, 1, 'diary of a wimpy kid: hard luck', '', False),
#    (1, 1, 'diary of a wimpy kid: rodrick rules', '', False),
#    (1,
#     1,
#     'diary of a wimpy kid: the long haul - jeff kinney',
#     'jeff kinney',
#     False),
#    (1, 1, 'diary of a wimpy kid: the third', 'jeff kinney', False),
#    (1, 1, 'diary of a wimpy kid: the ugly truth', '', False),
#    (1, 1, 'diary of the whimpy kid', '', False),
#    (1, 1, 'diary of the wimpy kid: the long haul', 'jeff kinney', False),
#    (1, 1, 'diary of wimpy kid doubble down', 'jeff kinney', False)]),
#  (199,
#   141,
#   'if you give a mouse a cookie',
#   'laura numeroff',
#   [(70, 39, 'if you give a mouse a cookie', 'laura numeroff', True),
#    (20, 19, 'if you give a moose a muffin', 'laura numeroff', True),
#    (21, 19, 'if you give a pig a pancake', 'laura numeroff', True),
#    (34, 16, 'if you give a cat a cupcake', 'laura numeroff', True),
#    (17, 16, 'if you give a dog a donut', 'laura numeroff', True),
#    (13, 13, 'if you take a mouse to school', 'laura numeroff', True),
#    (10, 10, 'if you take a mouse to the movies', 'laura numeroff', True),
#    (14, 9, 'if you give a pig a party', 'laura numeroff', True)],
#   []),
#  (114,
#   105,
#   'goodnight moon',
#   'margaret wise brown',
#   [(113, 104, 'goodnight moon', 'margaret wise brown', True),
#    (1, 1, 'goodnight moon 123', 'margaret wise brown', True)],
#   []),
#  (117,
#   92,
#   'green eggs and ham',
#   'dr. seuss',
#   [(117, 92, 'green eggs and ham', 'dr. seuss', True)],
#   []),
#  (166,
#   89,
#   'chicka chicka boom boom',
#   'martin, bill',
#   [(77, 42, 'chicka chicka boom boom', 'martin, bill', True),
#    (29,
#     23,
#     'chicka chicka boom boom',
#     'bill martin jr. & john archamba',
#     True),
#    (9, 9, 'chicka chicka abc', 'martin, bill', True),
#    (9, 5, 'chicka chicka 1 2 3', 'bill martin jr.', True),
#    (6,
#     3,
#     'chicka chicka boom boom',
#     'bill martin jr, john archambault',
#     True)],
#   [(32, 4, 'chicka chicka 123', 'bill martin', False),
#    (2, 1, 'chicka chicka boo', '', False),
#    (1,
#     1,
#     'chicka chicka boom boom',
#     'by bill martin john jrarchambault',
#     False),
#    (1, 1, 'chicka chicka boom boom', 'by bill martin jr', False)]),
#  (118,
#   83,
#   'i am going!',
#   'mo willems',
#   [(11, 10, 'i am going!', 'mo willems', True),
#    (11, 10, 'i am going!', 'mo willems', True),
#    (7, 6, 'i am invited to a party!', 'mo willems', True),
#    (7, 6, 'i am invited to a party!', 'mo willems', True),
#    (1, 1, 'a big guy took my ball!', 'mo willems', True),
#    (1, 1, 'a big guy took my ball!', 'mo willems', True)],
#   [(24, 15, 'can i play too?', 'willems, mo', False),
#    (28, 12, 'can i play, too?', 'mo willems', False),
#    (11, 10, 'a big guy took my ball!', 'mo willems', False),
#    (11, 10, 'a big guy took my ball!', 'mo willems', False),
#    (6, 2, 'can i play too?', 'mo willems', False)])]

# %% [markdown]
# ### Exporting the Data
# Now that we're finished clustering the books, it's time to export the results to an accessible format.  We'll put them in two dataframes, cluster_df and book_df, each of which will be exported to an excel file.
#
# cluster_df will contain only the title, author, and count of the cluster.  If users wish to see the books contained in a particular cluster, they can search for that cluster id in the "books" file.

# %%
counts=[]
readers=[]
titles=[]
authors=[]

cluster_ids=[]
book_counts=[]
book_readers=[]
book_titles=[]
book_authors=[]
is_openlibrarys=[]

cluster_id = 0
for c in l:
    counts.append(c.get_count())
    readers.append(c.get_readers())
    titles.append(c.get_title())
    authors.append(c.get_author())
    
    contents = c.get_contents_list()
    for book in contents:
        cluster_ids.append(cluster_id)
        book_counts.append(book.count)
        book_readers.append(book.readers)
        book_titles.append(book.title)
        book_authors.append(book.author)
        is_openlibrarys.append(book.is_openlibrary)
    cluster_id = cluster_id + 1

# %%
cluster_df = pd.DataFrame(collections.OrderedDict([
    ('count', counts),
    ('readers', readers),
    ('title', titles),
    ('author', authors)
     ]))
cluster_df[:10]
# Out:
#    count  readers                                  title               author
# 0    412      378  harry potter and the sorcerer's stone        j. k. rowling
# 1    458      327                         curious george            h. a. rey
# 2    189      185                     captain underpants           dav pilkey
# 3    183      165                            fancy nancy        jane o'connor
# 4    160      156                   diary of a wimpy kid          jeff kinney
# 5    199      141           if you give a mouse a cookie       laura numeroff
# 6    114      105                         goodnight moon  margaret wise brown
# 7    117       92                     green eggs and ham            dr. seuss
# 8    166       89                chicka chicka boom boom         martin, bill
# 9    118       83                            i am going!           mo willems

# %%
book_df = pd.DataFrame(collections.OrderedDict([
    ('cluster_id', cluster_ids),
    ('count', book_counts),
    ('readers', book_readers),
    ('title', book_titles),
    ('author', book_authors),
    ('is_openlibrary', is_openlibrarys)
     ]))
book_df[:10]
# Out:
#    cluster_id  count  readers                                      title  \
# 0           0     99       87      harry potter and the sorcerer's stone
# 1           0     60       59    harry potter and the chamber of secrets
# 2           0     61       54        harry potter and the goblet of fire
# 3           0     48       44  harry potter and the order of the phoenix
# 4           0     42       40   harry potter and the prisoner of azkaban
# 5           0     39       38     harry potter and the half-blood prince
# 6           0     38       31       harry potter and the deathly hallows
# 7           0     23       23          harry potter and the cursed child
# 8           0      1        1   harry potter and the philosopher's stone
# 9           0      1        1                       harry potter, tome 3
#
#           author  is_openlibrary
# 0  j. k. rowling            True
# 1  j. k. rowling            True
# 2  j. k. rowling            True
# 3  j. k. rowling            True
# 4  j. k. rowling            True
# 5  j. k. rowling            True
# 6  j. k. rowling            True
# 7  j. k. rowling            True
# 8  j. k. rowling            True
# 9  j. k. rowling            True

# %%
pandas_import_and_export.to_csv(cluster_df, "cluster_df")
pandas_import_and_export.to_csv(book_df, "book_df")
